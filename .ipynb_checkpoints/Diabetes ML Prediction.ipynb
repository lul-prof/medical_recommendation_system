# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score

# %%
#loading dataset
data=pd.read_csv('diabetes.csv')

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
data.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
data.describe
# Out:
# <bound method NDFrame.describe of      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
data.shape
# Out:
# (768, 9)

# %%
data['Outcome'].value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %% [raw]
# 0--->Non Diabetic Person
# 1--->Diabetic Person

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
data.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  109.980000      68.184000      19.664000   68.792000
# 1           4.865672  141.257463      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164

# %%
#splitting the data
X=data.drop(columns='Outcome', axis=1)
Y=data['Outcome']

# %%
X
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %%
Y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
#standardization of the data

scaler=StandardScaler()
scaler.fit(X)
# Out:
# StandardScaler()

# %%
standardized_data=scaler.transform(X)

# %%
standardized_data
# Out:
# array([[ 0.63994726,  0.84832379,  0.14964075, ...,  0.20401277,
#          0.46849198,  1.4259954 ],
#        [-0.84488505, -1.12339636, -0.16054575, ..., -0.68442195,
#         -0.36506078, -0.19067191],
#        [ 1.23388019,  1.94372388, -0.26394125, ..., -1.10325546,
#          0.60439732, -0.10558415],
#        ...,
#        [ 0.3429808 ,  0.00330087,  0.14964075, ..., -0.73518964,
#         -0.68519336, -0.27575966],
#        [-0.84488505,  0.1597866 , -0.47073225, ..., -0.24020459,
#         -0.37110101,  1.17073215],
#        [-0.84488505, -0.8730192 ,  0.04624525, ..., -0.20212881,
#         -0.47378505, -0.87137393]])

# %%
X=standardized_data
Y=data['Outcome']

# %%
X
# Out:
# array([[ 0.63994726,  0.84832379,  0.14964075, ...,  0.20401277,
#          0.46849198,  1.4259954 ],
#        [-0.84488505, -1.12339636, -0.16054575, ..., -0.68442195,
#         -0.36506078, -0.19067191],
#        [ 1.23388019,  1.94372388, -0.26394125, ..., -1.10325546,
#          0.60439732, -0.10558415],
#        ...,
#        [ 0.3429808 ,  0.00330087,  0.14964075, ..., -0.73518964,
#         -0.68519336, -0.27575966],
#        [-0.84488505,  0.1597866 , -0.47073225, ..., -0.24020459,
#         -0.37110101,  1.17073215],
#        [-0.84488505, -0.8730192 ,  0.04624525, ..., -0.20212881,
#         -0.47378505, -0.87137393]])

# %%
#Train Test Split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.2, stratify=Y, random_state=2)

# %%
X.shape, X_train.shape, X_test.shape
# Out:
# ((768, 8), (614, 8), (154, 8))

# %%
#Traing the Model

# %%
scaler=StandardScaler()
scaler.fit(X_train)
X_train_std=scaler.transform(X_train) #fit and transform training data
X_test_std=scaler.transform(X_test) #transform test data

# %%
classifier=svm.SVC(kernel='linear')

# %%
classifier.fit(X_train_std, Y_train)
# Out:
# SVC(kernel='linear')

# %%
#Model Evaluation

# %%
#Accuracy Score based on Training data

X_train_prediction=classifier.predict(X_train_std)
training_data_accuracy=accuracy_score(X_train_prediction, Y_train)

# %%
print('Accuracy Score Training data::', training_data_accuracy)
# Out:
# Accuracy Score Training data:: 0.7866449511400652

# %%
#Accuracy Score based on Test data

X_test_prediction=classifier.predict(X_test_std)
test_data_accuracy=accuracy_score(X_test_prediction, Y_test)

# %%
print('Accuracy Score Test data::', test_data_accuracy)
# Out:
# Accuracy Score Test data:: 0.7727272727272727

# %%
test_data_accuracy
# Out:
# 0.7727272727272727

# %%
#Testing the Model with Known Values

# %%
#save the model

# %%
import pickle
pickle.dump({'model' : classifier, 'scaler' : scaler}, open("diabetes_model_scaler.pkl",'wb'))

# %%
#load the model
classifiers=pickle.load(open("diabetes_model_scaler.pkl",'rb'))
classifier=classifiers['model']

# %%
input_data=(1,89,66,23,94,28.1,0.167,21)

#change input data to numpy array
input_data_as_numpy_array = np.asarray(input_data)

#reshape the array as we are predicting for one instance
input_data_reshaped=input_data_as_numpy_array.reshape(1,-1)

#standardize the input data
std_data=scaler.transform(input_data_reshaped)
print(std_data)

prediction=classifier.predict(std_data)
print(prediction)

if (prediction[0]==0):
    print("Person Not Diabetic")
else:
    print("Person Is Diabetic")
# Out:
# [[ 1.00009371 89.5990599  65.29144819 22.80530275 91.35400174 27.6655069
#    0.16962011 21.02094026]]
# [1]
# Person Is Diabetic

# %%
#Testing with Uknown Values
pregnancies=input('Enter Pregnancies:')
Glucose=input('Enter Glucose:')
Blood_Pressure=input('Enter Blood Pressure:')
Skin_Thickness=input('Enter Skin Thickness:')
BMI=input('Enter BMI:')
Insulin=input('Enter Insulin:')
Diabetes_Pedigree_Function=input('Enter Diabetes Pedigree Function:')
Age=input('Enter Age:')
input_data=(pregnancies,Glucose,Blood_Pressure,Skin_Thickness,BMI,Insulin,Diabetes_Pedigree_Function,Age)
#change input data to numpy array
input_data_as_numpy_array = np.asarray(input_data)

#reshape the array as we are predicting for one instance
input_data_reshaped=input_data_as_numpy_array.reshape(1,-1)

#standardize the input data
std_data=scaler.transform(input_data_reshaped)
print(std_data)

prediction=classifier.predict(std_data)
print(prediction)

if (prediction[0]==0):
    print("Person Not Diabetic")
else:
    print("Person Is Diabetic")
# Out:
# Enter Pregnancies: 6
# Enter Glucose: 4
# Enter Blood Pressure: 3
# Enter Skin Thickness: 2
# Enter BMI: 3
# Enter Insulin: 4
# Enter Diabetes Pedigree Function: 5
# Enter Age: 3
# [[5.99123942 4.00781801 2.94844733 1.97144527 2.88816182 3.91868045
#   4.94017735 3.00179092]]
# [1]
# Person Is Diabetic
